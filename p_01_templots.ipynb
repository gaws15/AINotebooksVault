# %% [markdown]
# <a href="https://colab.research.google.com/github/gaws15/AINotebooksVault/blob/main/p_01_templots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
time_points = np.array([25, 75, 125, 175, 225, 275, 325, 375, 425, 475, 525, 575, 625, 675, 725, 775])

temperatures = {
    'Layer 1':  [207, 140, 120, 114, 108, 93, 88, 84, 80, 78, 76, 74, 73, 71, 68, 65],
    'Layer 2':  [None, 150, 130, 124, 118, 103, 98, 94, 90, 88, 86, 84, 83, 81, 78, 75],
    'Layer 3':  [None, None, 138, 132, 126, 111, 106, 102, 98, 96, 94, 92, 91, 89, 86, 83],
    'Layer 4':  [None, None, None, 139, 133, 118, 113, 109, 105, 103, 101, 99, 98, 96, 93, 90],
    'Layer 5':  [None, None, None, None, 139, 124, 119, 115, 111, 109, 107, 105, 104, 102, 99, 96],
    'Layer 6':  [None, None, None, None, None, 129, 124, 120, 116, 114, 112, 110, 109, 107, 104, 101],
    'Layer 7':  [None, None, None, None, None, None, 128, 124, 120, 118, 116, 114, 113, 111, 108, 105],
    'Layer 8':  [None, None, None, None, None, None, None, 127, 123, 121, 119, 117, 116, 114, 111, 108],
    'Layer 9':  [None, None, None, None, None, None, None, None, 125, 123, 121, 119, 118, 116, 113, 110],
    'Layer 10': [None, None, None, None, None, None, None, None, None, 124, 122, 120, 119, 117, 114, 111]
}

# Create figure and axis
plt.figure(figsize=(12, 8))

# Plot each layer
colors = plt.cm.tab10(np.linspace(0, 1, len(temperatures)))
for (layer_name, temps), color in zip(temperatures.items(), colors):
    # Convert None to np.nan for proper plotting
    temp_array = np.array([t if t is not None else np.nan for t in temps])
    plt.plot(time_points, temp_array, marker='', linestyle='-', linewidth=2,
             label=layer_name, color=color)

# Customize the plot
plt.title('Temperature vs Time for Different Layers', fontsize=14, pad=20)
plt.xlabel('Time (s)', fontsize=12)
plt.ylabel('Temperature', fontsize=12)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

# Customize legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# Adjust layout to prevent legend cutoff
plt.tight_layout()

# Show plot
plt.show()

# Optional: Save the plot
# plt.savefig('temperature_layers.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ömer hoca 2.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
time_points = np.array([25, 75, 125, 175, 225, 275, 325, 375, 425, 475, 525, 575, 625, 675, 725, 775])

temperatures_dataset2 = {
    'Layer 1':  [115, 114, 102, 98, 92, 91, 86, 82, 80, 77, 75, 73, 72, 70, 67, 64],
    'Layer 2':  [None, 124, 112, 108, 102, 101, 96, 92, 90, 87, 85, 83, 82, 80, 77, 74],
    'Layer 3':  [None, None, 120, 116, 110, 109, 104, 100, 98, 95, 93, 91, 90, 88, 85, 82],
    'Layer 4':  [None, None, None, 123, 117, 116, 111, 107, 105, 102, 100, 98, 97, 95, 92, 89],
    'Layer 5':  [None, None, None, None, 123, 122, 117, 113, 111, 108, 106, 104, 103, 101, 98, 95],
    'Layer 6':  [None, None, None, None, None, 127, 122, 118, 116, 113, 111, 109, 108, 106, 103, 100],
    'Layer 7':  [None, None, None, None, None, None, 126, 122, 120, 117, 115, 113, 112, 110, 107, 104],
    'Layer 8':  [None, None, None, None, None, None, None, 125, 123, 120, 118, 116, 115, 113, 110, 107],
    'Layer 9':  [None, None, None, None, None, None, None, None, 125, 122, 120, 118, 117, 115, 112, 109],
    'Layer 10': [None, None, None, None, None, None, None, None, None, 123, 121, 119, 118, 116, 113, 110]
}
# Create figure and axis
plt.figure(figsize=(12, 8))

# Plot each layer
colors = plt.cm.tab10(np.linspace(0, 1, len(temperatures_dataset2)))
for (layer_name, temps), color in zip(temperatures_dataset2.items(), colors):
    # Convert None to np.nan for proper plotting
    temp_array = np.array([t if t is not None else np.nan for t in temps])
    plt.plot(time_points, temp_array, marker='', linestyle='-', linewidth=2,
             label=layer_name, color=color)

# Customize the plot
plt.title('Temperature vs Time for Different Layers', fontsize=14, pad=20)
plt.xlabel('Time (s)', fontsize=12)
plt.ylabel('Temperature', fontsize=12)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

# Customize legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# Adjust layout to prevent legend cutoff
plt.tight_layout()

# Show plot
plt.show()

# Optional: Save the plot
# plt.savefig('temperature_layers.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# temperatu vs bead height vs time plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns  # Import seaborn
# Generate sample data

# Generate sample data
def generate_data():
    time_points = np.array([25, 75, 125, 175, 225, 275, 325, 375, 425, 475])
    n_measurements = 10
    n_timepoints = len(time_points)

    # Reshape heights and temperatures to be 2D arrays
    heights = np.array([13.33333333,	12,	12,	11.33333333,	11.33333333,	11,	11,	10.66666667,	10.66666667,	10.66666667]).reshape(-1, 1)
    temperatures = np.array([115, 114, 102, 98, 92, 91, 86, 82, 80, 77]).reshape(-1, 1)

    return time_points, heights, temperatures

def create_monitoring_plot(time_points, heights, temperatures):

    sns.set_style('whitegrid')  # Use seaborn to set the style if desired
    fig = plt.figure(figsize=(15, 10))
    gs = GridSpec(2, 1, height_ratios=[2, 2], hspace=0.3)

    # Height plot
    ax1 = fig.add_subplot(gs[0])
    ax2 = fig.add_subplot(gs[1])
    # Plot individual measurements as light blue dots
    for i in range(heights.shape[1]):
        ax1.scatter(time_points, heights[:, i], color='lightblue', alpha=0.3, s=30)

    # Plot mean height as a blue line
    mean_height = np.mean(heights, axis=1)
    ax1.plot(time_points, mean_height, color='blue', linewidth=2, label='Mean Height')

    # Add standard deviation area
    std_height = np.std(heights, axis=1)
    ax1.fill_between(time_points,
                     mean_height - std_height,
                     mean_height + std_height,
                     color='blue', alpha=0.2, label='±1 STD')

    ax1.set_xlabel('Time (seconds)')
    ax1.set_ylabel('Layer Height (mm)')
    ax1.set_title('Layer Height Variation Over Time')
    ax1.grid(True, linestyle='--', alpha=0.7)
    ax1.legend()

    # Temperature plot
    ax2 = fig.add_subplot(gs[1])
    ax2.axhline(y=105, color='green', linestyle='--', label='tg=105')
    ax2.legend() # Update the legend to include the new line

    # Plot individual measurements as light red dots
    for i in range(temperatures.shape[1]):
        ax2.scatter(time_points, temperatures[:, i], color='mistyrose', alpha=0.3, s=30)

    # Plot mean temperature as a red line
    mean_temp = np.mean(temperatures, axis=1)
    ax2.plot(time_points, mean_temp, color='red', linewidth=2, label='Mean Temperature')

    # Add standard deviation area
    std_temp = np.std(temperatures, axis=1)
    ax2.fill_between(time_points,
                     mean_temp - std_temp,
                     mean_temp + std_temp,
                     color='red', alpha=0.2, label='±1 STD')

    ax2.set_xlabel('Time (seconds)')
    ax2.set_ylabel('Temperature (°C)')
    ax2.set_title('Temperature Variation Over Time')
    ax2.grid(True, linestyle='--', alpha=0.7)
    ax2.legend()

    plt.suptitle('3D Print Layer Monitoring', fontsize=16, y=1.02)

    # Add text box with statistics
    stats_text = (f'Height Stats:\n'
                 f'Mean: {np.mean(heights):.2f}mm\n'
                 f'Std: {np.std(heights):.2f}mm\n\n'
                 f'Temperature Stats:\n'
                 f'Mean: {np.mean(temperatures):.2f}°C\n'
                 f'Std: {np.std(temperatures):.2f}°C')

    plt.figtext(1.02, 0.5, stats_text, bbox=dict(facecolor='white', alpha=0.8),
                fontsize=10, ha='left', va='center')

    plt.tight_layout()
    return fig

# Generate and plot data
time_points, heights, temperatures = generate_data()
fig = create_monitoring_plot(time_points, heights, temperatures)

# Save the plot
plt.savefig('layer_monitoring.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# <ipython-input-10-93b0231cbf4b>:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np

# Example data for 10 layers
time_points = np.array([25, 75, 125, 175, 225, 275, 325, 375, 425, 475])

# Heights for 10 layers (each column is a layer)
heights = np.array([
    [4.67, 3.3333, 3.3333, 3.3333, 3.333, 3.3333, 3.333, 3, 3, 3],
    [np.nan, 8.3333, 7.3333, 7, 7.333, 7.3333, 7.333, 7, 7.333, 7],
    [np.nan, np.nan, 13, 11.333, 11.33, 11.333, 11.33, 11.33, 11.33, 11],
    [np.nan, np.nan, np.nan, 17, 16, 16, 16, 15.67, 16, 15.667,],
    [np.nan, np.nan, np.nan, np.nan, 22, 21, 20.67, 20.33, 20.67, 20.333],
    [np.nan, np.nan, np.nan, np.nan, np.nan, 27, 25.67, 25, 25, 24.667],
    [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 31.33, 30, 30, 29.667],
    [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 36, 34.67, 34.333],
    [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 40.67, 39.333],
    [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 45],

]).T  # Transpose to make each column a layer



# Temperatures for 10 layers (each column is a layer)
temperatures = np.array([
        [207, 140, 120, 114, 108, 93, 88, 84, 80, 78],
        [None, 150, 130, 124, 118, 103, 98, 94, 90, 88],
        [None, None, 138, 132, 126, 111, 106, 102, 98, 96],
        [None, None, None, 139, 133, 118, 113, 109, 105, 103],
        [None, None, None, None, 139, 124, 119, 115, 111, 109],
        [None, None, None, None, None, 129, 124, 120, 116, 114],
        [None, None, None, None, None, None, 128, 124, 120, 118],
        [None, None, None, None, None, None, None, 127, 123, 121],
        [None, None, None, None, None, None, None, None, 125, 123],
        [None, None, None, None, None, None, None, None, None, 124]
]).T  # Transpose to make each column a layer
